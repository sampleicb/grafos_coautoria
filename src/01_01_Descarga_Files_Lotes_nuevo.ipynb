# %%
from ftplib import FTP
import os
import time

# === CONFIGURACIÓN ===
ftp_host = "ftp.ncbi.nlm.nih.gov"
ftp_dir = "/pubmed/baseline/"
dbfs_target_dir = "/dbfs/FileStore/pubmed_baseline"

batch_size = 100           # Archivos por lote
sleep_seconds = 10         # Pausa entre lotes (segundos)
max_batches = None         # None = todos los lotes posibles, o pon un número para limitar

# Crear carpeta destino en DBFS si no existe
os.makedirs(dbfs_target_dir, exist_ok=True)

# === OBTENER LISTA DE ARCHIVOS DESDE FTP ===
ftp = FTP(ftp_host)
ftp.login()
ftp.cwd(ftp_dir)
all_files = [f for f in ftp.nlst() if f.endswith(".xml.gz")]
ftp.quit()

selected_files = sorted([f for f in all_files if f.startswith("pubmed25n")])

total_files = len(selected_files)
total_batches = (total_files + batch_size - 1) // batch_size

if max_batches:
    total_batches = min(total_batches, max_batches)

print(f"📂 Total archivos: {total_files} | Total lotes: {total_batches} | Tamaño de lote: {batch_size}")

# === FUNCIÓN DE DESCARGA ===
def download_ftp_file(file_name):
    import os
    from ftplib import FTP

    try:
        target_path = f"/dbfs/FileStore/pubmed_baseline/{file_name}"
        if os.path.exists(target_path):
            return f"✔️ {file_name} ya existe"

        ftp = FTP("ftp.ncbi.nlm.nih.gov")
        ftp.login()
        ftp.cwd("/pubmed/baseline/")
        with open(target_path, "wb") as f:
            ftp.retrbinary(f"RETR " + file_name, f.write)
        ftp.quit()
        return f"✅ {file_name} descargado"
    except Exception as e:
        return f"❌ Error {file_name}: {str(e)}"

# === LOOP POR LOTES ===
for batch_number in range(total_batches):
    start = batch_number * batch_size
    end = min(start + batch_size, total_files)

    batch_files = selected_files[start:end]

    existing_files = {f.name for f in dbutils.fs.ls("dbfs:/FileStore/pubmed_baseline")}
    files_to_download = [f for f in batch_files if f not in existing_files]

    print(f"\n🚀 Lote #{batch_number+1}/{total_batches} -> Archivos {start}–{end-1} ({len(files_to_download)} nuevos)")

    if not files_to_download:
        print("🎉 Todos los archivos de este lote ya están descargados.")
    else:
        rdd = spark.sparkContext.parallelize(files_to_download, numSlices=min(len(files_to_download), batch_size))
        resultados = rdd.map(download_ftp_file).collect()

        for r in resultados:
            print(r)

    if batch_number < total_batches - 1:
        print(f"⏳ Esperando {sleep_seconds} segundos antes del siguiente lote...")
        time.sleep(sleep_seconds)

print("\n✅ Descarga por lotes finalizada.")
# Out:
# 📂 Total archivos: 1274 | Total lotes: 13 | Tamaño de lote: 100
#
# 🚀 Lote #1/13 -> Archivos 0–99 (0 nuevos)
# 🎉 Todos los archivos de este lote ya están descargados.
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #2/13 -> Archivos 100–199 (100 nuevos)
# ✅ pubmed25n0101.xml.gz descargado
# ✅ pubmed25n0102.xml.gz descargado
# ✅ pubmed25n0103.xml.gz descargado
# ✅ pubmed25n0104.xml.gz descargado
# ✅ pubmed25n0105.xml.gz descargado
# ✅ pubmed25n0106.xml.gz descargado
# ✅ pubmed25n0107.xml.gz descargado
# ✅ pubmed25n0108.xml.gz descargado
# ✅ pubmed25n0109.xml.gz descargado
# ✅ pubmed25n0110.xml.gz descargado
# ✅ pubmed25n0111.xml.gz descargado
# ✅ pubmed25n0112.xml.gz descargado
# ✅ pubmed25n0113.xml.gz descargado
# ✅ pubmed25n0114.xml.gz descargado
# ✅ pubmed25n0115.xml.gz descargado
# ✅ pubmed25n0116.xml.gz descargado
# ✅ pubmed25n0117.xml.gz descargado
# ✅ pubmed25n0118.xml.gz descargado
# ✅ pubmed25n0119.xml.gz descargado
# ✅ pubmed25n0120.xml.gz descargado
# ✅ pubmed25n0121.xml.gz descargado
# ✅ pubmed25n0122.xml.gz descargado
# ✅ pubmed25n0123.xml.gz descargado
# ✅ pubmed25n0124.xml.gz descargado
# ✅ pubmed25n0125.xml.gz descargado
# ✅ pubmed25n0126.xml.gz descargado
# ✅ pubmed25n0127.xml.gz descargado
# ✅ pubmed25n0128.xml.gz descargado
# ✅ pubmed25n0129.xml.gz descargado
# ✅ pubmed25n0130.xml.gz descargado
# ✅ pubmed25n0131.xml.gz descargado
# ✅ pubmed25n0132.xml.gz descargado
# ✅ pubmed25n0133.xml.gz descargado
# ✅ pubmed25n0134.xml.gz descargado
# ✅ pubmed25n0135.xml.gz descargado
# ✅ pubmed25n0136.xml.gz descargado
# ✅ pubmed25n0137.xml.gz descargado
# ✅ pubmed25n0138.xml.gz descargado
# ✅ pubmed25n0139.xml.gz descargado
# ✅ pubmed25n0140.xml.gz descargado
# ✅ pubmed25n0141.xml.gz descargado
# ✅ pubmed25n0142.xml.gz descargado
# ✅ pubmed25n0143.xml.gz descargado
# ✅ pubmed25n0144.xml.gz descargado
# ✅ pubmed25n0145.xml.gz descargado
# ✅ pubmed25n0146.xml.gz descargado
# ✅ pubmed25n0147.xml.gz descargado
# ✅ pubmed25n0148.xml.gz descargado
# ✅ pubmed25n0149.xml.gz descargado
# ✅ pubmed25n0150.xml.gz descargado
# ✅ pubmed25n0151.xml.gz descargado
# ✅ pubmed25n0152.xml.gz descargado
# ✅ pubmed25n0153.xml.gz descargado
# ✅ pubmed25n0154.xml.gz descargado
# ✅ pubmed25n0155.xml.gz descargado
# ✅ pubmed25n0156.xml.gz descargado
# ✅ pubmed25n0157.xml.gz descargado
# ✅ pubmed25n0158.xml.gz descargado
# ✅ pubmed25n0159.xml.gz descargado
# ✅ pubmed25n0160.xml.gz descargado
# ✅ pubmed25n0161.xml.gz descargado
# ✅ pubmed25n0162.xml.gz descargado
# ✅ pubmed25n0163.xml.gz descargado
# ✅ pubmed25n0164.xml.gz descargado
# ✅ pubmed25n0165.xml.gz descargado
# ✅ pubmed25n0166.xml.gz descargado
# ✅ pubmed25n0167.xml.gz descargado
# ✅ pubmed25n0168.xml.gz descargado
# ✅ pubmed25n0169.xml.gz descargado
# ✅ pubmed25n0170.xml.gz descargado
# ✅ pubmed25n0171.xml.gz descargado
# ✅ pubmed25n0172.xml.gz descargado
# ✅ pubmed25n0173.xml.gz descargado
# ✅ pubmed25n0174.xml.gz descargado
# ✅ pubmed25n0175.xml.gz descargado
# ✅ pubmed25n0176.xml.gz descargado
# ✅ pubmed25n0177.xml.gz descargado
# ✅ pubmed25n0178.xml.gz descargado
# ✅ pubmed25n0179.xml.gz descargado
# ✅ pubmed25n0180.xml.gz descargado
# ✅ pubmed25n0181.xml.gz descargado
# ✅ pubmed25n0182.xml.gz descargado
# ✅ pubmed25n0183.xml.gz descargado
# ✅ pubmed25n0184.xml.gz descargado
# ✅ pubmed25n0185.xml.gz descargado
# ✅ pubmed25n0186.xml.gz descargado
# ✅ pubmed25n0187.xml.gz descargado
# ✅ pubmed25n0188.xml.gz descargado
# ✅ pubmed25n0189.xml.gz descargado
# ✅ pubmed25n0190.xml.gz descargado
# ✅ pubmed25n0191.xml.gz descargado
# ✅ pubmed25n0192.xml.gz descargado
# ✅ pubmed25n0193.xml.gz descargado
# ✅ pubmed25n0194.xml.gz descargado
# ✅ pubmed25n0195.xml.gz descargado
# ✅ pubmed25n0196.xml.gz descargado
# ✅ pubmed25n0197.xml.gz descargado
# ✅ pubmed25n0198.xml.gz descargado
# ✅ pubmed25n0199.xml.gz descargado
# ✅ pubmed25n0200.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #3/13 -> Archivos 200–299 (100 nuevos)
# ✅ pubmed25n0201.xml.gz descargado
# ✅ pubmed25n0202.xml.gz descargado
# ✅ pubmed25n0203.xml.gz descargado
# ✅ pubmed25n0204.xml.gz descargado
# ✅ pubmed25n0205.xml.gz descargado
# ✅ pubmed25n0206.xml.gz descargado
# ✅ pubmed25n0207.xml.gz descargado
# ✅ pubmed25n0208.xml.gz descargado
# ✅ pubmed25n0209.xml.gz descargado
# ✅ pubmed25n0210.xml.gz descargado
# ✅ pubmed25n0211.xml.gz descargado
# ✅ pubmed25n0212.xml.gz descargado
# ✅ pubmed25n0213.xml.gz descargado
# ✅ pubmed25n0214.xml.gz descargado
# ✅ pubmed25n0215.xml.gz descargado
# ✅ pubmed25n0216.xml.gz descargado
# ✅ pubmed25n0217.xml.gz descargado
# ✅ pubmed25n0218.xml.gz descargado
# ✅ pubmed25n0219.xml.gz descargado
# ✅ pubmed25n0220.xml.gz descargado
# ✅ pubmed25n0221.xml.gz descargado
# ✅ pubmed25n0222.xml.gz descargado
# ✅ pubmed25n0223.xml.gz descargado
# ✅ pubmed25n0224.xml.gz descargado
# ✅ pubmed25n0225.xml.gz descargado
# ✅ pubmed25n0226.xml.gz descargado
# ✅ pubmed25n0227.xml.gz descargado
# ✅ pubmed25n0228.xml.gz descargado
# ✅ pubmed25n0229.xml.gz descargado
# ✅ pubmed25n0230.xml.gz descargado
# ✅ pubmed25n0231.xml.gz descargado
# ✅ pubmed25n0232.xml.gz descargado
# ✅ pubmed25n0233.xml.gz descargado
# ✅ pubmed25n0234.xml.gz descargado
# ✅ pubmed25n0235.xml.gz descargado
# ✅ pubmed25n0236.xml.gz descargado
# ✅ pubmed25n0237.xml.gz descargado
# ✅ pubmed25n0238.xml.gz descargado
# ✅ pubmed25n0239.xml.gz descargado
# ✅ pubmed25n0240.xml.gz descargado
# ✅ pubmed25n0241.xml.gz descargado
# ✅ pubmed25n0242.xml.gz descargado
# ✅ pubmed25n0243.xml.gz descargado
# ✅ pubmed25n0244.xml.gz descargado
# ✅ pubmed25n0245.xml.gz descargado
# ✅ pubmed25n0246.xml.gz descargado
# ✅ pubmed25n0247.xml.gz descargado
# ✅ pubmed25n0248.xml.gz descargado
# ✅ pubmed25n0249.xml.gz descargado
# ✅ pubmed25n0250.xml.gz descargado
# ✅ pubmed25n0251.xml.gz descargado
# ✅ pubmed25n0252.xml.gz descargado
# ✅ pubmed25n0253.xml.gz descargado
# ✅ pubmed25n0254.xml.gz descargado
# ✅ pubmed25n0255.xml.gz descargado
# ✅ pubmed25n0256.xml.gz descargado
# ✅ pubmed25n0257.xml.gz descargado
# ✅ pubmed25n0258.xml.gz descargado
# ✅ pubmed25n0259.xml.gz descargado
# ✅ pubmed25n0260.xml.gz descargado
# ✅ pubmed25n0261.xml.gz descargado
# ✅ pubmed25n0262.xml.gz descargado
# ✅ pubmed25n0263.xml.gz descargado
# ✅ pubmed25n0264.xml.gz descargado
# ✅ pubmed25n0265.xml.gz descargado
# ✅ pubmed25n0266.xml.gz descargado
# ✅ pubmed25n0267.xml.gz descargado
# ✅ pubmed25n0268.xml.gz descargado
# ✅ pubmed25n0269.xml.gz descargado
# ✅ pubmed25n0270.xml.gz descargado
# ✅ pubmed25n0271.xml.gz descargado
# ✅ pubmed25n0272.xml.gz descargado
# ✅ pubmed25n0273.xml.gz descargado
# ✅ pubmed25n0274.xml.gz descargado
# ✅ pubmed25n0275.xml.gz descargado
# ✅ pubmed25n0276.xml.gz descargado
# ✅ pubmed25n0277.xml.gz descargado
# ✅ pubmed25n0278.xml.gz descargado
# ✅ pubmed25n0279.xml.gz descargado
# ✅ pubmed25n0280.xml.gz descargado
# ✅ pubmed25n0281.xml.gz descargado
# ✅ pubmed25n0282.xml.gz descargado
# ✅ pubmed25n0283.xml.gz descargado
# ✅ pubmed25n0284.xml.gz descargado
# ✅ pubmed25n0285.xml.gz descargado
# ✅ pubmed25n0286.xml.gz descargado
# ✅ pubmed25n0287.xml.gz descargado
# ✅ pubmed25n0288.xml.gz descargado
# ✅ pubmed25n0289.xml.gz descargado
# ✅ pubmed25n0290.xml.gz descargado
# ✅ pubmed25n0291.xml.gz descargado
# ✅ pubmed25n0292.xml.gz descargado
# ✅ pubmed25n0293.xml.gz descargado
# ✅ pubmed25n0294.xml.gz descargado
# ✅ pubmed25n0295.xml.gz descargado
# ✅ pubmed25n0296.xml.gz descargado
# ✅ pubmed25n0297.xml.gz descargado
# ✅ pubmed25n0298.xml.gz descargado
# ✅ pubmed25n0299.xml.gz descargado
# ✅ pubmed25n0300.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #4/13 -> Archivos 300–399 (100 nuevos)
# ✅ pubmed25n0301.xml.gz descargado
# ✅ pubmed25n0302.xml.gz descargado
# ✅ pubmed25n0303.xml.gz descargado
# ✅ pubmed25n0304.xml.gz descargado
# ✅ pubmed25n0305.xml.gz descargado
# ✅ pubmed25n0306.xml.gz descargado
# ✅ pubmed25n0307.xml.gz descargado
# ✅ pubmed25n0308.xml.gz descargado
# ✅ pubmed25n0309.xml.gz descargado
# ✅ pubmed25n0310.xml.gz descargado
# ✅ pubmed25n0311.xml.gz descargado
# ✅ pubmed25n0312.xml.gz descargado
# ✅ pubmed25n0313.xml.gz descargado
# ✅ pubmed25n0314.xml.gz descargado
# ✅ pubmed25n0315.xml.gz descargado
# ✅ pubmed25n0316.xml.gz descargado
# ✅ pubmed25n0317.xml.gz descargado
# ✅ pubmed25n0318.xml.gz descargado
# ✅ pubmed25n0319.xml.gz descargado
# ✅ pubmed25n0320.xml.gz descargado
# ✅ pubmed25n0321.xml.gz descargado
# ✅ pubmed25n0322.xml.gz descargado
# ✅ pubmed25n0323.xml.gz descargado
# ✅ pubmed25n0324.xml.gz descargado
# ✅ pubmed25n0325.xml.gz descargado
# ✅ pubmed25n0326.xml.gz descargado
# ✅ pubmed25n0327.xml.gz descargado
# ✅ pubmed25n0328.xml.gz descargado
# ✅ pubmed25n0329.xml.gz descargado
# ✅ pubmed25n0330.xml.gz descargado
# ✅ pubmed25n0331.xml.gz descargado
# ✅ pubmed25n0332.xml.gz descargado
# ✅ pubmed25n0333.xml.gz descargado
# ✅ pubmed25n0334.xml.gz descargado
# ✅ pubmed25n0335.xml.gz descargado
# ✅ pubmed25n0336.xml.gz descargado
# ✅ pubmed25n0337.xml.gz descargado
# ✅ pubmed25n0338.xml.gz descargado
# ✅ pubmed25n0339.xml.gz descargado
# ✅ pubmed25n0340.xml.gz descargado
# ✅ pubmed25n0341.xml.gz descargado
# ✅ pubmed25n0342.xml.gz descargado
# ✅ pubmed25n0343.xml.gz descargado
# ✅ pubmed25n0344.xml.gz descargado
# ✅ pubmed25n0345.xml.gz descargado
# ✅ pubmed25n0346.xml.gz descargado
# ✅ pubmed25n0347.xml.gz descargado
# ✅ pubmed25n0348.xml.gz descargado
# ✅ pubmed25n0349.xml.gz descargado
# ✅ pubmed25n0350.xml.gz descargado
# ✅ pubmed25n0351.xml.gz descargado
# ✅ pubmed25n0352.xml.gz descargado
# ✅ pubmed25n0353.xml.gz descargado
# ✅ pubmed25n0354.xml.gz descargado
# ✅ pubmed25n0355.xml.gz descargado
# ✅ pubmed25n0356.xml.gz descargado
# ✅ pubmed25n0357.xml.gz descargado
# ✅ pubmed25n0358.xml.gz descargado
# ✅ pubmed25n0359.xml.gz descargado
# ✅ pubmed25n0360.xml.gz descargado
# ✅ pubmed25n0361.xml.gz descargado
# ✅ pubmed25n0362.xml.gz descargado
# ✅ pubmed25n0363.xml.gz descargado
# ✅ pubmed25n0364.xml.gz descargado
# ✅ pubmed25n0365.xml.gz descargado
# ✅ pubmed25n0366.xml.gz descargado
# ✅ pubmed25n0367.xml.gz descargado
# ✅ pubmed25n0368.xml.gz descargado
# ✅ pubmed25n0369.xml.gz descargado
# ✅ pubmed25n0370.xml.gz descargado
# ✅ pubmed25n0371.xml.gz descargado
# ✅ pubmed25n0372.xml.gz descargado
# ✅ pubmed25n0373.xml.gz descargado
# ✅ pubmed25n0374.xml.gz descargado
# ✅ pubmed25n0375.xml.gz descargado
# ✅ pubmed25n0376.xml.gz descargado
# ✅ pubmed25n0377.xml.gz descargado
# ✅ pubmed25n0378.xml.gz descargado
# ✅ pubmed25n0379.xml.gz descargado
# ✅ pubmed25n0380.xml.gz descargado
# ✅ pubmed25n0381.xml.gz descargado
# ✅ pubmed25n0382.xml.gz descargado
# ✅ pubmed25n0383.xml.gz descargado
# ✅ pubmed25n0384.xml.gz descargado
# ✅ pubmed25n0385.xml.gz descargado
# ✅ pubmed25n0386.xml.gz descargado
# ✅ pubmed25n0387.xml.gz descargado
# ✅ pubmed25n0388.xml.gz descargado
# ✅ pubmed25n0389.xml.gz descargado
# ✅ pubmed25n0390.xml.gz descargado
# ✅ pubmed25n0391.xml.gz descargado
# ✅ pubmed25n0392.xml.gz descargado
# ✅ pubmed25n0393.xml.gz descargado
# ✅ pubmed25n0394.xml.gz descargado
# ✅ pubmed25n0395.xml.gz descargado
# ✅ pubmed25n0396.xml.gz descargado
# ✅ pubmed25n0397.xml.gz descargado
# ✅ pubmed25n0398.xml.gz descargado
# ✅ pubmed25n0399.xml.gz descargado
# ✅ pubmed25n0400.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #5/13 -> Archivos 400–499 (100 nuevos)
# ✅ pubmed25n0401.xml.gz descargado
# ✅ pubmed25n0402.xml.gz descargado
# ✅ pubmed25n0403.xml.gz descargado
# ✅ pubmed25n0404.xml.gz descargado
# ✅ pubmed25n0405.xml.gz descargado
# ✅ pubmed25n0406.xml.gz descargado
# ✅ pubmed25n0407.xml.gz descargado
# ✅ pubmed25n0408.xml.gz descargado
# ✅ pubmed25n0409.xml.gz descargado
# ✅ pubmed25n0410.xml.gz descargado
# ✅ pubmed25n0411.xml.gz descargado
# ✅ pubmed25n0412.xml.gz descargado
# ✅ pubmed25n0413.xml.gz descargado
# ✅ pubmed25n0414.xml.gz descargado
# ✅ pubmed25n0415.xml.gz descargado
# ✅ pubmed25n0416.xml.gz descargado
# ✅ pubmed25n0417.xml.gz descargado
# ✅ pubmed25n0418.xml.gz descargado
# ✅ pubmed25n0419.xml.gz descargado
# ✅ pubmed25n0420.xml.gz descargado
# ✅ pubmed25n0421.xml.gz descargado
# ✅ pubmed25n0422.xml.gz descargado
# ✅ pubmed25n0423.xml.gz descargado
# ✅ pubmed25n0424.xml.gz descargado
# ✅ pubmed25n0425.xml.gz descargado
# ✅ pubmed25n0426.xml.gz descargado
# ✅ pubmed25n0427.xml.gz descargado
# ✅ pubmed25n0428.xml.gz descargado
# ✅ pubmed25n0429.xml.gz descargado
# ✅ pubmed25n0430.xml.gz descargado
# ✅ pubmed25n0431.xml.gz descargado
# ✅ pubmed25n0432.xml.gz descargado
# ✅ pubmed25n0433.xml.gz descargado
# ✅ pubmed25n0434.xml.gz descargado
# ✅ pubmed25n0435.xml.gz descargado
# ✅ pubmed25n0436.xml.gz descargado
# ✅ pubmed25n0437.xml.gz descargado
# ✅ pubmed25n0438.xml.gz descargado
# ✅ pubmed25n0439.xml.gz descargado
# ✅ pubmed25n0440.xml.gz descargado
# ✅ pubmed25n0441.xml.gz descargado
# ✅ pubmed25n0442.xml.gz descargado
# ✅ pubmed25n0443.xml.gz descargado
# ✅ pubmed25n0444.xml.gz descargado
# ✅ pubmed25n0445.xml.gz descargado
# ✅ pubmed25n0446.xml.gz descargado
# ✅ pubmed25n0447.xml.gz descargado
# ✅ pubmed25n0448.xml.gz descargado
# ✅ pubmed25n0449.xml.gz descargado
# ✅ pubmed25n0450.xml.gz descargado
# ✅ pubmed25n0451.xml.gz descargado
# ✅ pubmed25n0452.xml.gz descargado
# ✅ pubmed25n0453.xml.gz descargado
# ✅ pubmed25n0454.xml.gz descargado
# ✅ pubmed25n0455.xml.gz descargado
# ✅ pubmed25n0456.xml.gz descargado
# ✅ pubmed25n0457.xml.gz descargado
# ✅ pubmed25n0458.xml.gz descargado
# ✅ pubmed25n0459.xml.gz descargado
# ✅ pubmed25n0460.xml.gz descargado
# ✅ pubmed25n0461.xml.gz descargado
# ✅ pubmed25n0462.xml.gz descargado
# ✅ pubmed25n0463.xml.gz descargado
# ✅ pubmed25n0464.xml.gz descargado
# ✅ pubmed25n0465.xml.gz descargado
# ✅ pubmed25n0466.xml.gz descargado
# ✅ pubmed25n0467.xml.gz descargado
# ✅ pubmed25n0468.xml.gz descargado
# ✅ pubmed25n0469.xml.gz descargado
# ✅ pubmed25n0470.xml.gz descargado
# ✅ pubmed25n0471.xml.gz descargado
# ✅ pubmed25n0472.xml.gz descargado
# ✅ pubmed25n0473.xml.gz descargado
# ✅ pubmed25n0474.xml.gz descargado
# ✅ pubmed25n0475.xml.gz descargado
# ✅ pubmed25n0476.xml.gz descargado
# ✅ pubmed25n0477.xml.gz descargado
# ✅ pubmed25n0478.xml.gz descargado
# ✅ pubmed25n0479.xml.gz descargado
# ✅ pubmed25n0480.xml.gz descargado
# ✅ pubmed25n0481.xml.gz descargado
# ✅ pubmed25n0482.xml.gz descargado
# ✅ pubmed25n0483.xml.gz descargado
# ✅ pubmed25n0484.xml.gz descargado
# ✅ pubmed25n0485.xml.gz descargado
# ✅ pubmed25n0486.xml.gz descargado
# ✅ pubmed25n0487.xml.gz descargado
# ✅ pubmed25n0488.xml.gz descargado
# ✅ pubmed25n0489.xml.gz descargado
# ✅ pubmed25n0490.xml.gz descargado
# ✅ pubmed25n0491.xml.gz descargado
# ✅ pubmed25n0492.xml.gz descargado
# ✅ pubmed25n0493.xml.gz descargado
# ✅ pubmed25n0494.xml.gz descargado
# ✅ pubmed25n0495.xml.gz descargado
# ✅ pubmed25n0496.xml.gz descargado
# ✅ pubmed25n0497.xml.gz descargado
# ✅ pubmed25n0498.xml.gz descargado
# ✅ pubmed25n0499.xml.gz descargado
# ✅ pubmed25n0500.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #6/13 -> Archivos 500–599 (100 nuevos)
# ✅ pubmed25n0501.xml.gz descargado
# ✅ pubmed25n0502.xml.gz descargado
# ✅ pubmed25n0503.xml.gz descargado
# ✅ pubmed25n0504.xml.gz descargado
# ✅ pubmed25n0505.xml.gz descargado
# ✅ pubmed25n0506.xml.gz descargado
# ✅ pubmed25n0507.xml.gz descargado
# ✅ pubmed25n0508.xml.gz descargado
# ✅ pubmed25n0509.xml.gz descargado
# ✅ pubmed25n0510.xml.gz descargado
# ✅ pubmed25n0511.xml.gz descargado
# ✅ pubmed25n0512.xml.gz descargado
# ✅ pubmed25n0513.xml.gz descargado
# ✅ pubmed25n0514.xml.gz descargado
# ✅ pubmed25n0515.xml.gz descargado
# ✅ pubmed25n0516.xml.gz descargado
# ✅ pubmed25n0517.xml.gz descargado
# ✅ pubmed25n0518.xml.gz descargado
# ✅ pubmed25n0519.xml.gz descargado
# ✅ pubmed25n0520.xml.gz descargado
# ✅ pubmed25n0521.xml.gz descargado
# ✅ pubmed25n0522.xml.gz descargado
# ✅ pubmed25n0523.xml.gz descargado
# ✅ pubmed25n0524.xml.gz descargado
# ✅ pubmed25n0525.xml.gz descargado
# ✅ pubmed25n0526.xml.gz descargado
# ✅ pubmed25n0527.xml.gz descargado
# ✅ pubmed25n0528.xml.gz descargado
# ✅ pubmed25n0529.xml.gz descargado
# ✅ pubmed25n0530.xml.gz descargado
# ✅ pubmed25n0531.xml.gz descargado
# ✅ pubmed25n0532.xml.gz descargado
# ✅ pubmed25n0533.xml.gz descargado
# ✅ pubmed25n0534.xml.gz descargado
# ✅ pubmed25n0535.xml.gz descargado
# ✅ pubmed25n0536.xml.gz descargado
# ✅ pubmed25n0537.xml.gz descargado
# ✅ pubmed25n0538.xml.gz descargado
# ✅ pubmed25n0539.xml.gz descargado
# ✅ pubmed25n0540.xml.gz descargado
# ✅ pubmed25n0541.xml.gz descargado
# ✅ pubmed25n0542.xml.gz descargado
# ✅ pubmed25n0543.xml.gz descargado
# ✅ pubmed25n0544.xml.gz descargado
# ✅ pubmed25n0545.xml.gz descargado
# ✅ pubmed25n0546.xml.gz descargado
# ✅ pubmed25n0547.xml.gz descargado
# ✅ pubmed25n0548.xml.gz descargado
# ✅ pubmed25n0549.xml.gz descargado
# ✅ pubmed25n0550.xml.gz descargado
# ✅ pubmed25n0551.xml.gz descargado
# ✅ pubmed25n0552.xml.gz descargado
# ✅ pubmed25n0553.xml.gz descargado
# ✅ pubmed25n0554.xml.gz descargado
# ✅ pubmed25n0555.xml.gz descargado
# ✅ pubmed25n0556.xml.gz descargado
# ✅ pubmed25n0557.xml.gz descargado
# ✅ pubmed25n0558.xml.gz descargado
# ✅ pubmed25n0559.xml.gz descargado
# ✅ pubmed25n0560.xml.gz descargado
# ✅ pubmed25n0561.xml.gz descargado
# ✅ pubmed25n0562.xml.gz descargado
# ✅ pubmed25n0563.xml.gz descargado
# ✅ pubmed25n0564.xml.gz descargado
# ✅ pubmed25n0565.xml.gz descargado
# ✅ pubmed25n0566.xml.gz descargado
# ✅ pubmed25n0567.xml.gz descargado
# ✅ pubmed25n0568.xml.gz descargado
# ✅ pubmed25n0569.xml.gz descargado
# ✅ pubmed25n0570.xml.gz descargado
# ✅ pubmed25n0571.xml.gz descargado
# ✅ pubmed25n0572.xml.gz descargado
# ✅ pubmed25n0573.xml.gz descargado
# ✅ pubmed25n0574.xml.gz descargado
# ✅ pubmed25n0575.xml.gz descargado
# ✅ pubmed25n0576.xml.gz descargado
# ✅ pubmed25n0577.xml.gz descargado
# ✅ pubmed25n0578.xml.gz descargado
# ✅ pubmed25n0579.xml.gz descargado
# ✅ pubmed25n0580.xml.gz descargado
# ✅ pubmed25n0581.xml.gz descargado
# ✅ pubmed25n0582.xml.gz descargado
# ✅ pubmed25n0583.xml.gz descargado
# ✅ pubmed25n0584.xml.gz descargado
# ✅ pubmed25n0585.xml.gz descargado
# ✅ pubmed25n0586.xml.gz descargado
# ✅ pubmed25n0587.xml.gz descargado
# ✅ pubmed25n0588.xml.gz descargado
# ✅ pubmed25n0589.xml.gz descargado
# ✅ pubmed25n0590.xml.gz descargado
# ✅ pubmed25n0591.xml.gz descargado
# ✅ pubmed25n0592.xml.gz descargado
# ✅ pubmed25n0593.xml.gz descargado
# ✅ pubmed25n0594.xml.gz descargado
# ✅ pubmed25n0595.xml.gz descargado
# ✅ pubmed25n0596.xml.gz descargado
# ✅ pubmed25n0597.xml.gz descargado
# ✅ pubmed25n0598.xml.gz descargado
# ✅ pubmed25n0599.xml.gz descargado
# ✅ pubmed25n0600.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #7/13 -> Archivos 600–699 (100 nuevos)
# ✅ pubmed25n0601.xml.gz descargado
# ✅ pubmed25n0602.xml.gz descargado
# ✅ pubmed25n0603.xml.gz descargado
# ✅ pubmed25n0604.xml.gz descargado
# ✅ pubmed25n0605.xml.gz descargado
# ✅ pubmed25n0606.xml.gz descargado
# ✅ pubmed25n0607.xml.gz descargado
# ✅ pubmed25n0608.xml.gz descargado
# ✅ pubmed25n0609.xml.gz descargado
# ✅ pubmed25n0610.xml.gz descargado
# ✅ pubmed25n0611.xml.gz descargado
# ✅ pubmed25n0612.xml.gz descargado
# ✅ pubmed25n0613.xml.gz descargado
# ✅ pubmed25n0614.xml.gz descargado
# ✅ pubmed25n0615.xml.gz descargado
# ✅ pubmed25n0616.xml.gz descargado
# ✅ pubmed25n0617.xml.gz descargado
# ✅ pubmed25n0618.xml.gz descargado
# ✅ pubmed25n0619.xml.gz descargado
# ✅ pubmed25n0620.xml.gz descargado
# ✅ pubmed25n0621.xml.gz descargado
# ✅ pubmed25n0622.xml.gz descargado
# ✅ pubmed25n0623.xml.gz descargado
# ✅ pubmed25n0624.xml.gz descargado
# ✅ pubmed25n0625.xml.gz descargado
# ✅ pubmed25n0626.xml.gz descargado
# ✅ pubmed25n0627.xml.gz descargado
# ✅ pubmed25n0628.xml.gz descargado
# ✅ pubmed25n0629.xml.gz descargado
# ✅ pubmed25n0630.xml.gz descargado
# ✅ pubmed25n0631.xml.gz descargado
# ✅ pubmed25n0632.xml.gz descargado
# ✅ pubmed25n0633.xml.gz descargado
# ✅ pubmed25n0634.xml.gz descargado
# ✅ pubmed25n0635.xml.gz descargado
# ✅ pubmed25n0636.xml.gz descargado
# ✅ pubmed25n0637.xml.gz descargado
# ✅ pubmed25n0638.xml.gz descargado
# ✅ pubmed25n0639.xml.gz descargado
# ✅ pubmed25n0640.xml.gz descargado
# ✅ pubmed25n0641.xml.gz descargado
# ✅ pubmed25n0642.xml.gz descargado
# ✅ pubmed25n0643.xml.gz descargado
# ✅ pubmed25n0644.xml.gz descargado
# ✅ pubmed25n0645.xml.gz descargado
# ✅ pubmed25n0646.xml.gz descargado
# ✅ pubmed25n0647.xml.gz descargado
# ✅ pubmed25n0648.xml.gz descargado
# ✅ pubmed25n0649.xml.gz descargado
# ✅ pubmed25n0650.xml.gz descargado
# ✅ pubmed25n0651.xml.gz descargado
# ✅ pubmed25n0652.xml.gz descargado
# ✅ pubmed25n0653.xml.gz descargado
# ✅ pubmed25n0654.xml.gz descargado
# ✅ pubmed25n0655.xml.gz descargado
# ✅ pubmed25n0656.xml.gz descargado
# ✅ pubmed25n0657.xml.gz descargado
# ✅ pubmed25n0658.xml.gz descargado
# ✅ pubmed25n0659.xml.gz descargado
# ✅ pubmed25n0660.xml.gz descargado
# ✅ pubmed25n0661.xml.gz descargado
# ✅ pubmed25n0662.xml.gz descargado
# ✅ pubmed25n0663.xml.gz descargado
# ✅ pubmed25n0664.xml.gz descargado
# ✅ pubmed25n0665.xml.gz descargado
# ✅ pubmed25n0666.xml.gz descargado
# ✅ pubmed25n0667.xml.gz descargado
# ✅ pubmed25n0668.xml.gz descargado
# ✅ pubmed25n0669.xml.gz descargado
# ✅ pubmed25n0670.xml.gz descargado
# ✅ pubmed25n0671.xml.gz descargado
# ✅ pubmed25n0672.xml.gz descargado
# ✅ pubmed25n0673.xml.gz descargado
# ✅ pubmed25n0674.xml.gz descargado
# ✅ pubmed25n0675.xml.gz descargado
# ✅ pubmed25n0676.xml.gz descargado
# ✅ pubmed25n0677.xml.gz descargado
# ✅ pubmed25n0678.xml.gz descargado
# ✅ pubmed25n0679.xml.gz descargado
# ✅ pubmed25n0680.xml.gz descargado
# ✅ pubmed25n0681.xml.gz descargado
# ✅ pubmed25n0682.xml.gz descargado
# ✅ pubmed25n0683.xml.gz descargado
# ✅ pubmed25n0684.xml.gz descargado
# ✅ pubmed25n0685.xml.gz descargado
# ✅ pubmed25n0686.xml.gz descargado
# ✅ pubmed25n0687.xml.gz descargado
# ✅ pubmed25n0688.xml.gz descargado
# ✅ pubmed25n0689.xml.gz descargado
# ✅ pubmed25n0690.xml.gz descargado
# ✅ pubmed25n0691.xml.gz descargado
# ✅ pubmed25n0692.xml.gz descargado
# ✅ pubmed25n0693.xml.gz descargado
# ✅ pubmed25n0694.xml.gz descargado
# ✅ pubmed25n0695.xml.gz descargado
# ✅ pubmed25n0696.xml.gz descargado
# ✅ pubmed25n0697.xml.gz descargado
# ✅ pubmed25n0698.xml.gz descargado
# ✅ pubmed25n0699.xml.gz descargado
# ✅ pubmed25n0700.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #8/13 -> Archivos 700–799 (100 nuevos)
# ✅ pubmed25n0701.xml.gz descargado
# ✅ pubmed25n0702.xml.gz descargado
# ✅ pubmed25n0703.xml.gz descargado
# ✅ pubmed25n0704.xml.gz descargado
# ✅ pubmed25n0705.xml.gz descargado
# ✅ pubmed25n0706.xml.gz descargado
# ✅ pubmed25n0707.xml.gz descargado
# ✅ pubmed25n0708.xml.gz descargado
# ✅ pubmed25n0709.xml.gz descargado
# ✅ pubmed25n0710.xml.gz descargado
# ✅ pubmed25n0711.xml.gz descargado
# ✅ pubmed25n0712.xml.gz descargado
# ✅ pubmed25n0713.xml.gz descargado
# ✅ pubmed25n0714.xml.gz descargado
# ✅ pubmed25n0715.xml.gz descargado
# ✅ pubmed25n0716.xml.gz descargado
# ✅ pubmed25n0717.xml.gz descargado
# ✅ pubmed25n0718.xml.gz descargado
# ✅ pubmed25n0719.xml.gz descargado
# ✅ pubmed25n0720.xml.gz descargado
# ✅ pubmed25n0721.xml.gz descargado
# ✅ pubmed25n0722.xml.gz descargado
# ✅ pubmed25n0723.xml.gz descargado
# ✅ pubmed25n0724.xml.gz descargado
# ✅ pubmed25n0725.xml.gz descargado
# ✅ pubmed25n0726.xml.gz descargado
# ✅ pubmed25n0727.xml.gz descargado
# ✅ pubmed25n0728.xml.gz descargado
# ✅ pubmed25n0729.xml.gz descargado
# ✅ pubmed25n0730.xml.gz descargado
# ✅ pubmed25n0731.xml.gz descargado
# ✅ pubmed25n0732.xml.gz descargado
# ✅ pubmed25n0733.xml.gz descargado
# ✅ pubmed25n0734.xml.gz descargado
# ✅ pubmed25n0735.xml.gz descargado
# ✅ pubmed25n0736.xml.gz descargado
# ✅ pubmed25n0737.xml.gz descargado
# ✅ pubmed25n0738.xml.gz descargado
# ✅ pubmed25n0739.xml.gz descargado
# ✅ pubmed25n0740.xml.gz descargado
# ✅ pubmed25n0741.xml.gz descargado
# ✅ pubmed25n0742.xml.gz descargado
# ✅ pubmed25n0743.xml.gz descargado
# ✅ pubmed25n0744.xml.gz descargado
# ✅ pubmed25n0745.xml.gz descargado
# ✅ pubmed25n0746.xml.gz descargado
# ✅ pubmed25n0747.xml.gz descargado
# ✅ pubmed25n0748.xml.gz descargado
# ✅ pubmed25n0749.xml.gz descargado
# ✅ pubmed25n0750.xml.gz descargado
# ✅ pubmed25n0751.xml.gz descargado
# ✅ pubmed25n0752.xml.gz descargado
# ✅ pubmed25n0753.xml.gz descargado
# ✅ pubmed25n0754.xml.gz descargado
# ✅ pubmed25n0755.xml.gz descargado
# ✅ pubmed25n0756.xml.gz descargado
# ✅ pubmed25n0757.xml.gz descargado
# ✅ pubmed25n0758.xml.gz descargado
# ✅ pubmed25n0759.xml.gz descargado
# ✅ pubmed25n0760.xml.gz descargado
# ✅ pubmed25n0761.xml.gz descargado
# ✅ pubmed25n0762.xml.gz descargado
# ✅ pubmed25n0763.xml.gz descargado
# ✅ pubmed25n0764.xml.gz descargado
# ✅ pubmed25n0765.xml.gz descargado
# ✅ pubmed25n0766.xml.gz descargado
# ✅ pubmed25n0767.xml.gz descargado
# ✅ pubmed25n0768.xml.gz descargado
# ✅ pubmed25n0769.xml.gz descargado
# ✅ pubmed25n0770.xml.gz descargado
# ✅ pubmed25n0771.xml.gz descargado
# ✅ pubmed25n0772.xml.gz descargado
# ✅ pubmed25n0773.xml.gz descargado
# ✅ pubmed25n0774.xml.gz descargado
# ✅ pubmed25n0775.xml.gz descargado
# ✅ pubmed25n0776.xml.gz descargado
# ✅ pubmed25n0777.xml.gz descargado
# ✅ pubmed25n0778.xml.gz descargado
# ✅ pubmed25n0779.xml.gz descargado
# ✅ pubmed25n0780.xml.gz descargado
# ✅ pubmed25n0781.xml.gz descargado
# ✅ pubmed25n0782.xml.gz descargado
# ✅ pubmed25n0783.xml.gz descargado
# ✅ pubmed25n0784.xml.gz descargado
# ✅ pubmed25n0785.xml.gz descargado
# ✅ pubmed25n0786.xml.gz descargado
# ✅ pubmed25n0787.xml.gz descargado
# ✅ pubmed25n0788.xml.gz descargado
# ✅ pubmed25n0789.xml.gz descargado
# ✅ pubmed25n0790.xml.gz descargado
# ✅ pubmed25n0791.xml.gz descargado
# ✅ pubmed25n0792.xml.gz descargado
# ✅ pubmed25n0793.xml.gz descargado
# ✅ pubmed25n0794.xml.gz descargado
# ✅ pubmed25n0795.xml.gz descargado
# ✅ pubmed25n0796.xml.gz descargado
# ✅ pubmed25n0797.xml.gz descargado
# ✅ pubmed25n0798.xml.gz descargado
# ✅ pubmed25n0799.xml.gz descargado
# ✅ pubmed25n0800.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #9/13 -> Archivos 800–899 (100 nuevos)
# ✅ pubmed25n0801.xml.gz descargado
# ✅ pubmed25n0802.xml.gz descargado
# ✅ pubmed25n0803.xml.gz descargado
# ✅ pubmed25n0804.xml.gz descargado
# ✅ pubmed25n0805.xml.gz descargado
# ✅ pubmed25n0806.xml.gz descargado
# ✅ pubmed25n0807.xml.gz descargado
# ✅ pubmed25n0808.xml.gz descargado
# ✅ pubmed25n0809.xml.gz descargado
# ✅ pubmed25n0810.xml.gz descargado
# ✅ pubmed25n0811.xml.gz descargado
# ✅ pubmed25n0812.xml.gz descargado
# ✅ pubmed25n0813.xml.gz descargado
# ✅ pubmed25n0814.xml.gz descargado
# ✅ pubmed25n0815.xml.gz descargado
# ✅ pubmed25n0816.xml.gz descargado
# ✅ pubmed25n0817.xml.gz descargado
# ✅ pubmed25n0818.xml.gz descargado
# ✅ pubmed25n0819.xml.gz descargado
# ✅ pubmed25n0820.xml.gz descargado
# ✅ pubmed25n0821.xml.gz descargado
# ✅ pubmed25n0822.xml.gz descargado
# ✅ pubmed25n0823.xml.gz descargado
# ✅ pubmed25n0824.xml.gz descargado
# ✅ pubmed25n0825.xml.gz descargado
# ✅ pubmed25n0826.xml.gz descargado
# ✅ pubmed25n0827.xml.gz descargado
# ✅ pubmed25n0828.xml.gz descargado
# ✅ pubmed25n0829.xml.gz descargado
# ✅ pubmed25n0830.xml.gz descargado
# ✅ pubmed25n0831.xml.gz descargado
# ✅ pubmed25n0832.xml.gz descargado
# ✅ pubmed25n0833.xml.gz descargado
# ✅ pubmed25n0834.xml.gz descargado
# ✅ pubmed25n0835.xml.gz descargado
# ✅ pubmed25n0836.xml.gz descargado
# ✅ pubmed25n0837.xml.gz descargado
# ✅ pubmed25n0838.xml.gz descargado
# ✅ pubmed25n0839.xml.gz descargado
# ✅ pubmed25n0840.xml.gz descargado
# ✅ pubmed25n0841.xml.gz descargado
# ✅ pubmed25n0842.xml.gz descargado
# ✅ pubmed25n0843.xml.gz descargado
# ✅ pubmed25n0844.xml.gz descargado
# ✅ pubmed25n0845.xml.gz descargado
# ✅ pubmed25n0846.xml.gz descargado
# ✅ pubmed25n0847.xml.gz descargado
# ✅ pubmed25n0848.xml.gz descargado
# ✅ pubmed25n0849.xml.gz descargado
# ✅ pubmed25n0850.xml.gz descargado
# ✅ pubmed25n0851.xml.gz descargado
# ✅ pubmed25n0852.xml.gz descargado
# ✅ pubmed25n0853.xml.gz descargado
# ✅ pubmed25n0854.xml.gz descargado
# ✅ pubmed25n0855.xml.gz descargado
# ✅ pubmed25n0856.xml.gz descargado
# ✅ pubmed25n0857.xml.gz descargado
# ✅ pubmed25n0858.xml.gz descargado
# ✅ pubmed25n0859.xml.gz descargado
# ✅ pubmed25n0860.xml.gz descargado
# ✅ pubmed25n0861.xml.gz descargado
# ✅ pubmed25n0862.xml.gz descargado
# ✅ pubmed25n0863.xml.gz descargado
# ✅ pubmed25n0864.xml.gz descargado
# ✅ pubmed25n0865.xml.gz descargado
# ✅ pubmed25n0866.xml.gz descargado
# ✅ pubmed25n0867.xml.gz descargado
# ✅ pubmed25n0868.xml.gz descargado
# ✅ pubmed25n0869.xml.gz descargado
# ✅ pubmed25n0870.xml.gz descargado
# ✅ pubmed25n0871.xml.gz descargado
# ✅ pubmed25n0872.xml.gz descargado
# ✅ pubmed25n0873.xml.gz descargado
# ✅ pubmed25n0874.xml.gz descargado
# ✅ pubmed25n0875.xml.gz descargado
# ✅ pubmed25n0876.xml.gz descargado
# ✅ pubmed25n0877.xml.gz descargado
# ✅ pubmed25n0878.xml.gz descargado
# ✅ pubmed25n0879.xml.gz descargado
# ✅ pubmed25n0880.xml.gz descargado
# ✅ pubmed25n0881.xml.gz descargado
# ✅ pubmed25n0882.xml.gz descargado
# ✅ pubmed25n0883.xml.gz descargado
# ✅ pubmed25n0884.xml.gz descargado
# ✅ pubmed25n0885.xml.gz descargado
# ✅ pubmed25n0886.xml.gz descargado
# ✅ pubmed25n0887.xml.gz descargado
# ✅ pubmed25n0888.xml.gz descargado
# ✅ pubmed25n0889.xml.gz descargado
# ✅ pubmed25n0890.xml.gz descargado
# ✅ pubmed25n0891.xml.gz descargado
# ✅ pubmed25n0892.xml.gz descargado
# ✅ pubmed25n0893.xml.gz descargado
# ✅ pubmed25n0894.xml.gz descargado
# ✅ pubmed25n0895.xml.gz descargado
# ✅ pubmed25n0896.xml.gz descargado
# ✅ pubmed25n0897.xml.gz descargado
# ✅ pubmed25n0898.xml.gz descargado
# ✅ pubmed25n0899.xml.gz descargado
# ✅ pubmed25n0900.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #10/13 -> Archivos 900–999 (100 nuevos)
# ✅ pubmed25n0901.xml.gz descargado
# ✅ pubmed25n0902.xml.gz descargado
# ✅ pubmed25n0903.xml.gz descargado
# ✅ pubmed25n0904.xml.gz descargado
# ✅ pubmed25n0905.xml.gz descargado
# ✅ pubmed25n0906.xml.gz descargado
# ✅ pubmed25n0907.xml.gz descargado
# ✅ pubmed25n0908.xml.gz descargado
# ✅ pubmed25n0909.xml.gz descargado
# ✅ pubmed25n0910.xml.gz descargado
# ✅ pubmed25n0911.xml.gz descargado
# ✅ pubmed25n0912.xml.gz descargado
# ✅ pubmed25n0913.xml.gz descargado
# ✅ pubmed25n0914.xml.gz descargado
# ✅ pubmed25n0915.xml.gz descargado
# ✅ pubmed25n0916.xml.gz descargado
# ✅ pubmed25n0917.xml.gz descargado
# ✅ pubmed25n0918.xml.gz descargado
# ✅ pubmed25n0919.xml.gz descargado
# ✅ pubmed25n0920.xml.gz descargado
# ✅ pubmed25n0921.xml.gz descargado
# ✅ pubmed25n0922.xml.gz descargado
# ✅ pubmed25n0923.xml.gz descargado
# ✅ pubmed25n0924.xml.gz descargado
# ✅ pubmed25n0925.xml.gz descargado
# ✅ pubmed25n0926.xml.gz descargado
# ✅ pubmed25n0927.xml.gz descargado
# ✅ pubmed25n0928.xml.gz descargado
# ✅ pubmed25n0929.xml.gz descargado
# ✅ pubmed25n0930.xml.gz descargado
# ✅ pubmed25n0931.xml.gz descargado
# ✅ pubmed25n0932.xml.gz descargado
# ✅ pubmed25n0933.xml.gz descargado
# ✅ pubmed25n0934.xml.gz descargado
# ✅ pubmed25n0935.xml.gz descargado
# ✅ pubmed25n0936.xml.gz descargado
# ✅ pubmed25n0937.xml.gz descargado
# ✅ pubmed25n0938.xml.gz descargado
# ✅ pubmed25n0939.xml.gz descargado
# ✅ pubmed25n0940.xml.gz descargado
# ✅ pubmed25n0941.xml.gz descargado
# ✅ pubmed25n0942.xml.gz descargado
# ✅ pubmed25n0943.xml.gz descargado
# ✅ pubmed25n0944.xml.gz descargado
# ✅ pubmed25n0945.xml.gz descargado
# ✅ pubmed25n0946.xml.gz descargado
# ✅ pubmed25n0947.xml.gz descargado
# ✅ pubmed25n0948.xml.gz descargado
# ✅ pubmed25n0949.xml.gz descargado
# ✅ pubmed25n0950.xml.gz descargado
# ✅ pubmed25n0951.xml.gz descargado
# ✅ pubmed25n0952.xml.gz descargado
# ✅ pubmed25n0953.xml.gz descargado
# ✅ pubmed25n0954.xml.gz descargado
# ✅ pubmed25n0955.xml.gz descargado
# ✅ pubmed25n0956.xml.gz descargado
# ✅ pubmed25n0957.xml.gz descargado
# ✅ pubmed25n0958.xml.gz descargado
# ✅ pubmed25n0959.xml.gz descargado
# ✅ pubmed25n0960.xml.gz descargado
# ✅ pubmed25n0961.xml.gz descargado
# ✅ pubmed25n0962.xml.gz descargado
# ✅ pubmed25n0963.xml.gz descargado
# ✅ pubmed25n0964.xml.gz descargado
# ✅ pubmed25n0965.xml.gz descargado
# ✅ pubmed25n0966.xml.gz descargado
# ✅ pubmed25n0967.xml.gz descargado
# ✅ pubmed25n0968.xml.gz descargado
# ✅ pubmed25n0969.xml.gz descargado
# ✅ pubmed25n0970.xml.gz descargado
# ✅ pubmed25n0971.xml.gz descargado
# ✅ pubmed25n0972.xml.gz descargado
# ✅ pubmed25n0973.xml.gz descargado
# ✅ pubmed25n0974.xml.gz descargado
# ✅ pubmed25n0975.xml.gz descargado
# ✅ pubmed25n0976.xml.gz descargado
# ✅ pubmed25n0977.xml.gz descargado
# ✅ pubmed25n0978.xml.gz descargado
# ✅ pubmed25n0979.xml.gz descargado
# ✅ pubmed25n0980.xml.gz descargado
# ✅ pubmed25n0981.xml.gz descargado
# ✅ pubmed25n0982.xml.gz descargado
# ✅ pubmed25n0983.xml.gz descargado
# ✅ pubmed25n0984.xml.gz descargado
# ✅ pubmed25n0985.xml.gz descargado
# ✅ pubmed25n0986.xml.gz descargado
# ✅ pubmed25n0987.xml.gz descargado
# ✅ pubmed25n0988.xml.gz descargado
# ✅ pubmed25n0989.xml.gz descargado
# ✅ pubmed25n0990.xml.gz descargado
# ✅ pubmed25n0991.xml.gz descargado
# ✅ pubmed25n0992.xml.gz descargado
# ✅ pubmed25n0993.xml.gz descargado
# ✅ pubmed25n0994.xml.gz descargado
# ✅ pubmed25n0995.xml.gz descargado
# ✅ pubmed25n0996.xml.gz descargado
# ✅ pubmed25n0997.xml.gz descargado
# ✅ pubmed25n0998.xml.gz descargado
# ✅ pubmed25n0999.xml.gz descargado
# ✅ pubmed25n1000.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #11/13 -> Archivos 1000–1099 (100 nuevos)
# ✅ pubmed25n1001.xml.gz descargado
# ✅ pubmed25n1002.xml.gz descargado
# ✅ pubmed25n1003.xml.gz descargado
# ✅ pubmed25n1004.xml.gz descargado
# ✅ pubmed25n1005.xml.gz descargado
# ✅ pubmed25n1006.xml.gz descargado
# ✅ pubmed25n1007.xml.gz descargado
# ✅ pubmed25n1008.xml.gz descargado
# ✅ pubmed25n1009.xml.gz descargado
# ✅ pubmed25n1010.xml.gz descargado
# ✅ pubmed25n1011.xml.gz descargado
# ✅ pubmed25n1012.xml.gz descargado
# ✅ pubmed25n1013.xml.gz descargado
# ✅ pubmed25n1014.xml.gz descargado
# ✅ pubmed25n1015.xml.gz descargado
# ✅ pubmed25n1016.xml.gz descargado
# ✅ pubmed25n1017.xml.gz descargado
# ✅ pubmed25n1018.xml.gz descargado
# ✅ pubmed25n1019.xml.gz descargado
# ✅ pubmed25n1020.xml.gz descargado
# ✅ pubmed25n1021.xml.gz descargado
# ✅ pubmed25n1022.xml.gz descargado
# ✅ pubmed25n1023.xml.gz descargado
# ✅ pubmed25n1024.xml.gz descargado
# ✅ pubmed25n1025.xml.gz descargado
# ✅ pubmed25n1026.xml.gz descargado
# ✅ pubmed25n1027.xml.gz descargado
# ✅ pubmed25n1028.xml.gz descargado
# ✅ pubmed25n1029.xml.gz descargado
# ✅ pubmed25n1030.xml.gz descargado
# ✅ pubmed25n1031.xml.gz descargado
# ✅ pubmed25n1032.xml.gz descargado
# ✅ pubmed25n1033.xml.gz descargado
# ✅ pubmed25n1034.xml.gz descargado
# ✅ pubmed25n1035.xml.gz descargado
# ✅ pubmed25n1036.xml.gz descargado
# ✅ pubmed25n1037.xml.gz descargado
# ✅ pubmed25n1038.xml.gz descargado
# ✅ pubmed25n1039.xml.gz descargado
# ✅ pubmed25n1040.xml.gz descargado
# ✅ pubmed25n1041.xml.gz descargado
# ✅ pubmed25n1042.xml.gz descargado
# ✅ pubmed25n1043.xml.gz descargado
# ✅ pubmed25n1044.xml.gz descargado
# ✅ pubmed25n1045.xml.gz descargado
# ✅ pubmed25n1046.xml.gz descargado
# ✅ pubmed25n1047.xml.gz descargado
# ✅ pubmed25n1048.xml.gz descargado
# ✅ pubmed25n1049.xml.gz descargado
# ✅ pubmed25n1050.xml.gz descargado
# ✅ pubmed25n1051.xml.gz descargado
# ✅ pubmed25n1052.xml.gz descargado
# ✅ pubmed25n1053.xml.gz descargado
# ✅ pubmed25n1054.xml.gz descargado
# ✅ pubmed25n1055.xml.gz descargado
# ✅ pubmed25n1056.xml.gz descargado
# ✅ pubmed25n1057.xml.gz descargado
# ✅ pubmed25n1058.xml.gz descargado
# ✅ pubmed25n1059.xml.gz descargado
# ✅ pubmed25n1060.xml.gz descargado
# ✅ pubmed25n1061.xml.gz descargado
# ✅ pubmed25n1062.xml.gz descargado
# ✅ pubmed25n1063.xml.gz descargado
# ✅ pubmed25n1064.xml.gz descargado
# ✅ pubmed25n1065.xml.gz descargado
# ✅ pubmed25n1066.xml.gz descargado
# ✅ pubmed25n1067.xml.gz descargado
# ✅ pubmed25n1068.xml.gz descargado
# ✅ pubmed25n1069.xml.gz descargado
# ✅ pubmed25n1070.xml.gz descargado
# ✅ pubmed25n1071.xml.gz descargado
# ✅ pubmed25n1072.xml.gz descargado
# ✅ pubmed25n1073.xml.gz descargado
# ✅ pubmed25n1074.xml.gz descargado
# ✅ pubmed25n1075.xml.gz descargado
# ✅ pubmed25n1076.xml.gz descargado
# ✅ pubmed25n1077.xml.gz descargado
# ✅ pubmed25n1078.xml.gz descargado
# ✅ pubmed25n1079.xml.gz descargado
# ✅ pubmed25n1080.xml.gz descargado
# ✅ pubmed25n1081.xml.gz descargado
# ✅ pubmed25n1082.xml.gz descargado
# ✅ pubmed25n1083.xml.gz descargado
# ✅ pubmed25n1084.xml.gz descargado
# ✅ pubmed25n1085.xml.gz descargado
# ✅ pubmed25n1086.xml.gz descargado
# ✅ pubmed25n1087.xml.gz descargado
# ✅ pubmed25n1088.xml.gz descargado
# ✅ pubmed25n1089.xml.gz descargado
# ✅ pubmed25n1090.xml.gz descargado
# ✅ pubmed25n1091.xml.gz descargado
# ✅ pubmed25n1092.xml.gz descargado
# ✅ pubmed25n1093.xml.gz descargado
# ✅ pubmed25n1094.xml.gz descargado
# ✅ pubmed25n1095.xml.gz descargado
# ✅ pubmed25n1096.xml.gz descargado
# ✅ pubmed25n1097.xml.gz descargado
# ✅ pubmed25n1098.xml.gz descargado
# ✅ pubmed25n1099.xml.gz descargado
# ✅ pubmed25n1100.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #12/13 -> Archivos 1100–1199 (100 nuevos)
# ✅ pubmed25n1101.xml.gz descargado
# ✅ pubmed25n1102.xml.gz descargado
# ✅ pubmed25n1103.xml.gz descargado
# ✅ pubmed25n1104.xml.gz descargado
# ✅ pubmed25n1105.xml.gz descargado
# ✅ pubmed25n1106.xml.gz descargado
# ✅ pubmed25n1107.xml.gz descargado
# ✅ pubmed25n1108.xml.gz descargado
# ✅ pubmed25n1109.xml.gz descargado
# ✅ pubmed25n1110.xml.gz descargado
# ✅ pubmed25n1111.xml.gz descargado
# ✅ pubmed25n1112.xml.gz descargado
# ✅ pubmed25n1113.xml.gz descargado
# ✅ pubmed25n1114.xml.gz descargado
# ✅ pubmed25n1115.xml.gz descargado
# ✅ pubmed25n1116.xml.gz descargado
# ✅ pubmed25n1117.xml.gz descargado
# ✅ pubmed25n1118.xml.gz descargado
# ✅ pubmed25n1119.xml.gz descargado
# ✅ pubmed25n1120.xml.gz descargado
# ✅ pubmed25n1121.xml.gz descargado
# ✅ pubmed25n1122.xml.gz descargado
# ✅ pubmed25n1123.xml.gz descargado
# ✅ pubmed25n1124.xml.gz descargado
# ✅ pubmed25n1125.xml.gz descargado
# ✅ pubmed25n1126.xml.gz descargado
# ✅ pubmed25n1127.xml.gz descargado
# ✅ pubmed25n1128.xml.gz descargado
# ✅ pubmed25n1129.xml.gz descargado
# ✅ pubmed25n1130.xml.gz descargado
# ✅ pubmed25n1131.xml.gz descargado
# ✅ pubmed25n1132.xml.gz descargado
# ✅ pubmed25n1133.xml.gz descargado
# ✅ pubmed25n1134.xml.gz descargado
# ✅ pubmed25n1135.xml.gz descargado
# ✅ pubmed25n1136.xml.gz descargado
# ✅ pubmed25n1137.xml.gz descargado
# ✅ pubmed25n1138.xml.gz descargado
# ✅ pubmed25n1139.xml.gz descargado
# ✅ pubmed25n1140.xml.gz descargado
# ✅ pubmed25n1141.xml.gz descargado
# ✅ pubmed25n1142.xml.gz descargado
# ✅ pubmed25n1143.xml.gz descargado
# ✅ pubmed25n1144.xml.gz descargado
# ✅ pubmed25n1145.xml.gz descargado
# ✅ pubmed25n1146.xml.gz descargado
# ✅ pubmed25n1147.xml.gz descargado
# ✅ pubmed25n1148.xml.gz descargado
# ✅ pubmed25n1149.xml.gz descargado
# ✅ pubmed25n1150.xml.gz descargado
# ✅ pubmed25n1151.xml.gz descargado
# ✅ pubmed25n1152.xml.gz descargado
# ✅ pubmed25n1153.xml.gz descargado
# ✅ pubmed25n1154.xml.gz descargado
# ✅ pubmed25n1155.xml.gz descargado
# ✅ pubmed25n1156.xml.gz descargado
# ✅ pubmed25n1157.xml.gz descargado
# ✅ pubmed25n1158.xml.gz descargado
# ✅ pubmed25n1159.xml.gz descargado
# ✅ pubmed25n1160.xml.gz descargado
# ✅ pubmed25n1161.xml.gz descargado
# ✅ pubmed25n1162.xml.gz descargado
# ✅ pubmed25n1163.xml.gz descargado
# ✅ pubmed25n1164.xml.gz descargado
# ✅ pubmed25n1165.xml.gz descargado
# ✅ pubmed25n1166.xml.gz descargado
# ✅ pubmed25n1167.xml.gz descargado
# ✅ pubmed25n1168.xml.gz descargado
# ✅ pubmed25n1169.xml.gz descargado
# ✅ pubmed25n1170.xml.gz descargado
# ✅ pubmed25n1171.xml.gz descargado
# ✅ pubmed25n1172.xml.gz descargado
# ✅ pubmed25n1173.xml.gz descargado
# ✅ pubmed25n1174.xml.gz descargado
# ✅ pubmed25n1175.xml.gz descargado
# ✅ pubmed25n1176.xml.gz descargado
# ✅ pubmed25n1177.xml.gz descargado
# ✅ pubmed25n1178.xml.gz descargado
# ✅ pubmed25n1179.xml.gz descargado
# ✅ pubmed25n1180.xml.gz descargado
# ✅ pubmed25n1181.xml.gz descargado
# ✅ pubmed25n1182.xml.gz descargado
# ✅ pubmed25n1183.xml.gz descargado
# ✅ pubmed25n1184.xml.gz descargado
# ✅ pubmed25n1185.xml.gz descargado
# ✅ pubmed25n1186.xml.gz descargado
# ✅ pubmed25n1187.xml.gz descargado
# ✅ pubmed25n1188.xml.gz descargado
# ✅ pubmed25n1189.xml.gz descargado
# ✅ pubmed25n1190.xml.gz descargado
# ✅ pubmed25n1191.xml.gz descargado
# ✅ pubmed25n1192.xml.gz descargado
# ✅ pubmed25n1193.xml.gz descargado
# ✅ pubmed25n1194.xml.gz descargado
# ✅ pubmed25n1195.xml.gz descargado
# ✅ pubmed25n1196.xml.gz descargado
# ✅ pubmed25n1197.xml.gz descargado
# ✅ pubmed25n1198.xml.gz descargado
# ✅ pubmed25n1199.xml.gz descargado
# ✅ pubmed25n1200.xml.gz descargado
# ⏳ Esperando 10 segundos antes del siguiente lote...
#
# 🚀 Lote #13/13 -> Archivos 1200–1273 (74 nuevos)
# ✅ pubmed25n1201.xml.gz descargado
# ✅ pubmed25n1202.xml.gz descargado
# ✅ pubmed25n1203.xml.gz descargado
# ✅ pubmed25n1204.xml.gz descargado
# ✅ pubmed25n1205.xml.gz descargado
# ✅ pubmed25n1206.xml.gz descargado
# ✅ pubmed25n1207.xml.gz descargado
# ✅ pubmed25n1208.xml.gz descargado
# ✅ pubmed25n1209.xml.gz descargado
# ✅ pubmed25n1210.xml.gz descargado
# ✅ pubmed25n1211.xml.gz descargado
# ✅ pubmed25n1212.xml.gz descargado
# ✅ pubmed25n1213.xml.gz descargado
# ✅ pubmed25n1214.xml.gz descargado
# ✅ pubmed25n1215.xml.gz descargado
# ✅ pubmed25n1216.xml.gz descargado
# ✅ pubmed25n1217.xml.gz descargado
# ✅ pubmed25n1218.xml.gz descargado
# ✅ pubmed25n1219.xml.gz descargado
# ✅ pubmed25n1220.xml.gz descargado
# ✅ pubmed25n1221.xml.gz descargado
# ✅ pubmed25n1222.xml.gz descargado
# ✅ pubmed25n1223.xml.gz descargado
# ✅ pubmed25n1224.xml.gz descargado
# ✅ pubmed25n1225.xml.gz descargado
# ✅ pubmed25n1226.xml.gz descargado
# ✅ pubmed25n1227.xml.gz descargado
# ✅ pubmed25n1228.xml.gz descargado
# ✅ pubmed25n1229.xml.gz descargado
# ✅ pubmed25n1230.xml.gz descargado
# ✅ pubmed25n1231.xml.gz descargado
# ✅ pubmed25n1232.xml.gz descargado
# ✅ pubmed25n1233.xml.gz descargado
# ✅ pubmed25n1234.xml.gz descargado
# ✅ pubmed25n1235.xml.gz descargado
# ✅ pubmed25n1236.xml.gz descargado
# ✅ pubmed25n1237.xml.gz descargado
# ✅ pubmed25n1238.xml.gz descargado
# ✅ pubmed25n1239.xml.gz descargado
# ✅ pubmed25n1240.xml.gz descargado
# ✅ pubmed25n1241.xml.gz descargado
# ✅ pubmed25n1242.xml.gz descargado
# ✅ pubmed25n1243.xml.gz descargado
# ✅ pubmed25n1244.xml.gz descargado
# ✅ pubmed25n1245.xml.gz descargado
# ✅ pubmed25n1246.xml.gz descargado
# ✅ pubmed25n1247.xml.gz descargado
# ✅ pubmed25n1248.xml.gz descargado
# ✅ pubmed25n1249.xml.gz descargado
# ✅ pubmed25n1250.xml.gz descargado
# ✅ pubmed25n1251.xml.gz descargado
# ✅ pubmed25n1252.xml.gz descargado
# ✅ pubmed25n1253.xml.gz descargado
# ✅ pubmed25n1254.xml.gz descargado
# ✅ pubmed25n1255.xml.gz descargado
# ✅ pubmed25n1256.xml.gz descargado
# ✅ pubmed25n1257.xml.gz descargado
# ✅ pubmed25n1258.xml.gz descargado
# ✅ pubmed25n1259.xml.gz descargado
# ✅ pubmed25n1260.xml.gz descargado
# ✅ pubmed25n1261.xml.gz descargado
# ✅ pubmed25n1262.xml.gz descargado
# ✅ pubmed25n1263.xml.gz descargado
# ✅ pubmed25n1264.xml.gz descargado
# ✅ pubmed25n1265.xml.gz descargado
# ✅ pubmed25n1266.xml.gz descargado
# ✅ pubmed25n1267.xml.gz descargado
# ✅ pubmed25n1268.xml.gz descargado
# ✅ pubmed25n1269.xml.gz descargado
# ✅ pubmed25n1270.xml.gz descargado
# ✅ pubmed25n1271.xml.gz descargado
# ✅ pubmed25n1272.xml.gz descargado
# ✅ pubmed25n1273.xml.gz descargado
# ✅ pubmed25n1274.xml.gz descargado
#
# ✅ Descarga por lotes finalizada.

# %%
from pyspark.sql.functions import input_file_name


files = dbutils.fs.ls("dbfs:/FileStore/pubmed_baseline")

num_files = len(files)
total_size = sum(f.size for f in files)

print(f"Número de ficheros: {num_files}")
print(f"Tamaño total: {total_size/1024/1024:.2f} MB")
# Out:
# Número de ficheros: 1274
# Tamaño total: 47219.78 MB
